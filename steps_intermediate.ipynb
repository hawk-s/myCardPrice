# %%
from bs4 import BeautifulSoup
import json
import re

# Path to your saved HTML file
html_file_path = "base_singles.html"

# Base URL for generating links
base_url = "https://www.cardmarket.com/en/Pokemon/Products/Singles/"

try:
    # Load the HTML file
    with open(html_file_path, "r", encoding="utf-8") as file:
        html_content = file.read()

    # Parse the HTML content
    soup = BeautifulSoup(html_content, "html.parser")

    # Find the select element with name="idExpansion"
    sets = []
    select_tag = soup.find("select", {"name": "idExpansion"})
    if select_tag:
        for option in select_tag.find_all("option"):
            set_name = option.text.strip()
            set_id = option.get("value")
            if set_name and set_id and set_id != "0":  # Exclude "All" or empty values
                # Format the set name for the URL
                formatted_set_name = re.sub(r'[^\w\s-]', '', set_name)  # Remove special characters except spaces and hyphens
                formatted_set_name = formatted_set_name.replace(" ", "-")  # Replace spaces with hyphens
                formatted_set_name = formatted_set_name.replace("+", "")  # Remove '+' characters
                link = f"{base_url}{formatted_set_name}"
                sets.append({
                    "name": set_name,
                    "id": set_id,
                    "link": link
                })

    # Save the extracted data to a JSON file
    with open("pokemon_sets.json", "w", encoding="utf-8") as json_file:
        json.dump(sets, json_file, indent=2, ensure_ascii=False)

    # Print the extracted data
    print("Extracted sets:")
    for set_data in sets:
        print(set_data)

    print("\nSet data saved to 'pokemon_sets.json'")
except Exception as e:
    print(f"Error: {e}")
# Out:
# Extracted sets:
# {'name': '"W" Promos', 'id': '1606', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/W-Promos'}
# {'name': '10th Movie Commemoration Set', 'id': '4310', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/10th-Movie-Commemoration-Set'}
# {'name': '11th Movie Commemoration Set', 'id': '4299', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/11th-Movie-Commemoration-Set'}
# {'name': '151', 'id': '5402', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/151'}
# {'name': '25th Anniversary Collection', 'id': '4345', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/25th-Anniversary-Collection'}
# {'name': '25th Anniversary Edition', 'id': '4346', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/25th-Anniversary-Edition'}
# {'name': '25th Anniversary Golden Box', 'id': '4389', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/25th-Anniversary-Golden-Box'}
# {'name': 'ADV Expansion Pack', 'id': '5877', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/ADV-Expansion-Pack'}
# {'name': 'ADV Promos', 'id': '4350', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/ADV-Promos'}
# {'name': 'Advent of Arceus', 'id': '4280', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Advent-of-Arceus'}
# {'name': 'Alolan Moonlight', 'id': '3951', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Alolan-Moonlight'}
# {'name': 'Alter Genesis', 'id': '3801', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Alter-Genesis'}
# {'name': 'Ancient Origins', 'id': '1660', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Ancient-Origins'}
# {'name': 'Ancient Roar', 'id': '5478', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Ancient-Roar'}
# {'name': 'Aqua Deck Kit', 'id': '5867', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Aqua-Deck-Kit'}
# {'name': 'Aquapolis', 'id': '1537', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Aquapolis'}
# {'name': 'Arceus', 'id': '1565', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Arceus'}
# {'name': 'Arceus LV.X Deck: Grass & Fire', 'id': '4279', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Arceus-LVX-Deck-Grass--Fire'}
# {'name': 'Arceus LV.X Deck: Lightning & Psychic', 'id': '4278', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Arceus-LVX-Deck-Lightning--Psychic'}
# {'name': 'Ash vs Team Rocket Deck Kit', 'id': '3974', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Ash-vs-Team-Rocket-Deck-Kit'}
# {'name': 'Astral Radiance', 'id': '4979', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Astral-Radiance'}
# {'name': 'Awakened Heroes', 'id': '3926', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Awakened-Heroes'}
# {'name': 'Awakening Legends', 'id': '4508', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Awakening-Legends'}
# {'name': 'Awakening Psychic King', 'id': '4004', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Awakening-Psychic-King'}
# {'name': 'Bandit Ring', 'id': '4024', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Bandit-Ring'}
# {'name': 'Base Expansion Pack', 'id': '5021', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Base-Expansion-Pack'}
# {'name': 'Base Set', 'id': '1523', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Base-Set'}
# {'name': 'Base Set 2', 'id': '1527', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Base-Set-2'}
# {'name': 'Bastiodon the Defender', 'id': '4316', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Bastiodon-the-Defender'}
# {'name': 'Battle Academy 2024', 'id': '5890', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Battle-Academy-2024'}
# {'name': 'Battle Gift Set: Thundurus vs Tornadus', 'id': '4205', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Battle-Gift-Set-Thundurus-vs-Tornadus'}
# {'name': 'Battle Master Deck Chien-Pao ex', 'id': '5738', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Battle-Master-Deck-Chien-Pao-ex'}
# {'name': 'Battle Master Deck Tera Charizard ex', 'id': '5737', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Battle-Master-Deck-Tera-Charizard-ex'}
# {'name': 'Battle Region', 'id': '4441', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Battle-Region'}
# {'name': 'Battle Strength Decks', 'id': '4212', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Battle-Strength-Decks'}
# {'name': 'Battle Styles', 'id': '3675', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Battle-Styles'}
# {'name': 'Battle Theme Deck: Victini', 'id': '4211', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Battle-Theme-Deck-Victini'}
# {'name': 'Beat of the Frontier', 'id': '4286', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Beat-of-the-Frontier'}
# {'name': 'Beginning Set', 'id': '4216', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Beginning-Set'}
# {'name': 'Best of Game Cards Promos', 'id': '1605', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Best-of-Game-Cards-Promos'}
# {'name': 'Black & White', 'id': '1571', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Black--White'}
# {'name': 'Black Collection', 'id': '4214', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Black-Collection'}
# {'name': 'Black Deck Kit', 'id': '5726', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Black-Deck-Kit'}
# {'name': 'Black Kyurem EX Battle Strength Deck', 'id': '4190', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Black-Kyurem-EX-Battle-Strength-Deck'}
# {'name': 'Blastoise + Kyurem EX Combo Deck', 'id': '4181', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Blastoise--Kyurem-EX-Combo-Deck'}
# {'name': 'Blastoise Battle Starter Deck', 'id': '4270', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Blastoise-Battle-Starter-Deck'}
# {'name': 'Blue Shock', 'id': '4014', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Blue-Shock'}
# {'name': 'Blue Sky Stream', 'id': '4330', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Blue-Sky-Stream'}
# {'name': 'Bonds to the End of Time', 'id': '4289', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Bonds-to-the-End-of-Time'}
# {'name': 'Boundaries Crossed', 'id': '1577', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Boundaries-Crossed'}
# {'name': 'BREAK Starter Pack', 'id': '4089', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/BREAK-Starter-Pack'}
# {'name': 'BREAKpoint', 'id': '1687', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/BREAKpoint'}
# {'name': 'BREAKthrough', 'id': '1678', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/BREAKthrough'}
# {'name': 'Brilliant Stars', 'id': '4434', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Brilliant-Stars'}
# {'name': 'Burger King DP Promos 2008', 'id': '1622', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Burger-King-DP-Promos-2008'}
# {'name': 'Burger King Platinum Promos 2009', 'id': '5034', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Burger-King-Platinum-Promos-2009'}
# {'name': 'Burning Shadows', 'id': '1824', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Burning-Shadows'}
# {'name': 'BW Black Star Promos', 'id': '1611', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/BW-Black-Star-Promos'}
# {'name': 'BW Promos', 'id': '4218', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/BW-Promos'}
# {'name': 'BW Trainer Kit', 'id': '1630', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/BW-Trainer-Kit'}
# {'name': 'Call of Legends', 'id': '1570', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Call-of-Legends'}
# {'name': 'Celebrations', 'id': '4347', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Celebrations'}
# {'name': 'Celestial Storm', 'id': '2320', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Celestial-Storm'}
# {'name': 'Challenge from the Darkness', 'id': '4467', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Challenge-from-the-Darkness'}
# {'name': 'Champion Road', 'id': '3886', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Champion-Road'}
# {'name': 'Champion’s Path', 'id': '3419', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Champions-Path'}
# {'name': 'Charizard SP Half Deck', 'id': '4284', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Charizard-SP-Half-Deck'}
# {'name': 'Chilling Reign', 'id': '4174', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Chilling-Reign'}
# {'name': 'Chimchar DPt Half Deck', 'id': '4293', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Chimchar-DPt-Half-Deck'}
# {'name': 'Clash at the Summit', 'id': '4261', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Clash-at-the-Summit'}
# {'name': 'Clash of the Blue Sky', 'id': '5713', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Clash-of-the-Blue-Sky'}
# {'name': 'Clay Burst', 'id': '5315', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Clay-Burst'}
# {'name': 'Cold Flare', 'id': '4194', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Cold-Flare'}
# {'name': 'Collection Moon', 'id': '3966', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Collection-Moon'}
# {'name': 'Collection Sheet Journey Partners', 'id': '4217', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Collection-Sheet-Journey-Partners'}
# {'name': 'Collection Sun', 'id': '3971', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Collection-Sun'}
# {'name': 'Collection X', 'id': '4064', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Collection-X'}
# {'name': 'Collection Y', 'id': '4059', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Collection-Y'}
# {'name': 'Cosmic Eclipse', 'id': '2644', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Cosmic-Eclipse'}
# {'name': 'Crimson Haze', 'id': '5636', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Crimson-Haze'}
# {'name': 'Crimson Invasion', 'id': '1843', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Crimson-Invasion'}
# {'name': 'Crossing the Ruins...', 'id': '4507', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Crossing-the-Ruins'}
# {'name': 'Crown Zenith', 'id': '5201', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Crown-Zenith'}
# {'name': 'Cruel Traitor', 'id': '3994', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Cruel-Traitor'}
# {'name': 'Cry from the Mysterious', 'id': '4305', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Cry-from-the-Mysterious'}
# {'name': 'Cyber Judge', 'id': '5574', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Cyber-Judge'}
# {'name': 'Dark Explorers', 'id': '1575', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Dark-Explorers'}
# {'name': 'Dark Order', 'id': '3861', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Dark-Order'}
# {'name': 'Dark Phantasma', 'id': '5048', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Dark-Phantasma'}
# {'name': 'Dark Rush', 'id': '4204', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Dark-Rush'}
# {'name': 'Darkness Ablaze', 'id': '3199', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Darkness-Ablaze'}
# {'name': 'Darkness that Consumes Light', 'id': '3936', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Darkness-that-Consumes-Light'}
# {'name': 'Darkness, and to Light...', 'id': '4509', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Darkness-and-to-Light'}
# {'name': 'Dawn Dash', 'id': '4308', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Dawn-Dash'}
# {'name': 'Deoxys Constructed Starter Deck', 'id': '5728', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Deoxys-Constructed-Starter-Deck'}
# {'name': 'Detective Pikachu', 'id': '2438', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Detective-Pikachu'}
# {'name': 'Dialga DPt Half Deck', 'id': '4295', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Dialga-DPt-Half-Deck'}
# {'name': 'Dialga Half Deck', 'id': '4300', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Dialga-Half-Deck'}
# {'name': 'Dialga LV.X Constructed Standard Deck', 'id': '4312', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Dialga-LVX-Constructed-Standard-Deck'}
# {'name': 'Diamond & Pearl', 'id': '1555', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Diamond--Pearl'}
# {'name': 'Double Blaze', 'id': '3836', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Double-Blaze'}
# {'name': 'Double Crisis', 'id': '1648', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Double-Crisis'}
# {'name': 'DP Black Star Promos', 'id': '1609', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/DP-Black-Star-Promos'}
# {'name': 'DP Promos', 'id': '4322', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/DP-Promos'}
# {'name': 'DP Trainer Kit', 'id': '1628', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/DP-Trainer-Kit'}
# {'name': 'DPt Promos', 'id': '4298', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/DPt-Promos'}
# {'name': 'Dragon Blade', 'id': '4200', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Dragon-Blade'}
# {'name': 'Dragon Blast', 'id': '4201', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Dragon-Blast'}
# {'name': 'Dragon Majesty', 'id': '2351', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Dragon-Majesty'}
# {'name': 'Dragon Selection', 'id': '4203', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Dragon-Selection'}
# {'name': 'Dragon Storm', 'id': '3891', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Dragon-Storm'}
# {'name': 'Dragon Vault', 'id': '1636', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Dragon-Vault'}
# {'name': 'Dragons Exalted', 'id': '1576', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Dragons-Exalted'}
# {'name': 'Dream League', 'id': '3806', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Dream-League'}
# {'name': "Earth's Groudon ex Constructed Starter Deck", 'id': '5698', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Earths-Groudon-ex-Constructed-Starter-Deck'}
# {'name': 'Eevee GX Starter Sets', 'id': '4250', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Eevee-GX-Starter-Sets'}
# {'name': 'Eevee Heroes', 'id': '4239', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Eevee-Heroes'}
# {'name': 'Eevee Heroes VMAX Special Set', 'id': '4240', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Eevee-Heroes-VMAX-Special-Set'}
# {'name': 'Emboar EX vs Togekiss EX Deck Kit', 'id': '4238', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Emboar-EX-vs-Togekiss-EX-Deck-Kit'}
# {'name': 'Emerald Break', 'id': '4029', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Emerald-Break'}
# {'name': 'Emerging Powers', 'id': '1572', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Emerging-Powers'}
# {'name': "Entry Pack '08", 'id': '4306', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Entry-Pack-08'}
# {'name': "Everyone's Exciting Battle", 'id': '4187', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Everyones-Exciting-Battle'}
# {'name': 'Evolutions', 'id': '1742', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Evolutions'}
# {'name': 'Evolving Skies', 'id': '4328', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Evolving-Skies'}
# {'name': 'EX Battle Boost', 'id': '4180', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/EX-Battle-Boost'}
# {'name': 'EX Crystal Guardians', 'id': '1552', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/EX-Crystal-Guardians'}
# {'name': 'EX Delta Species', 'id': '1549', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/EX-Delta-Species'}
# {'name': 'EX Deoxys', 'id': '1546', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/EX-Deoxys'}
# {'name': 'EX Dragon', 'id': '1541', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/EX-Dragon'}
# {'name': 'EX Dragon Frontiers', 'id': '1553', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/EX-Dragon-Frontiers'}
# {'name': 'EX Emerald', 'id': '1547', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/EX-Emerald'}
# {'name': 'EX FireRed & LeafGreen', 'id': '1544', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/EX-FireRed--LeafGreen'}
# {'name': 'EX Hidden Legends', 'id': '1543', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/EX-Hidden-Legends'}
# {'name': 'EX Holon Phantoms', 'id': '1551', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/EX-Holon-Phantoms'}
# {'name': 'EX Legend Maker', 'id': '1550', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/EX-Legend-Maker'}
# {'name': 'EX Power Keepers', 'id': '1554', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/EX-Power-Keepers'}
# {'name': 'EX Ruby & Sapphire', 'id': '1539', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/EX-Ruby--Sapphire'}
# {'name': 'EX Sandstorm', 'id': '1540', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/EX-Sandstorm'}
# {'name': 'ex Start Decks', 'id': '5362', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/ex-Start-Decks'}
# {'name': 'ex Starter Set Fuecoco & Ampharos ex', 'id': '5219', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/ex-Starter-Set-Fuecoco--Ampharos-ex'}
# {'name': 'ex Starter Set Pikachu ex & Pawmot', 'id': '5299', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/ex-Starter-Set-Pikachu-ex--Pawmot'}
# {'name': 'ex Starter Set Quaxly & Mimikyu ex', 'id': '5220', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/ex-Starter-Set-Quaxly--Mimikyu-ex'}
# {'name': 'ex Starter Set Sprigatito & Lucario ex', 'id': '5218', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/ex-Starter-Set-Sprigatito--Lucario-ex'}
# {'name': 'EX Team Magma vs Team Aqua', 'id': '1542', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/EX-Team-Magma-vs-Team-Aqua'}
# {'name': 'EX Team Rocket Returns', 'id': '1545', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/EX-Team-Rocket-Returns'}
# {'name': 'EX Trainer Kit', 'id': '1626', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/EX-Trainer-Kit'}
# {'name': 'EX Trainer Kit 2', 'id': '1627', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/EX-Trainer-Kit-2'}
# {'name': 'EX Unseen Forces', 'id': '1548', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/EX-Unseen-Forces'}
# {'name': 'Expansion Pack', 'id': '4169', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Expansion-Pack'}
# {'name': 'Expansion Pack 20th Anniversary', 'id': '3989', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Expansion-Pack-20th-Anniversary'}
# {'name': 'Expansion Sheet', 'id': '3781', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Expansion-Sheet'}
# {'name': 'Expedition Base Set', 'id': '1536', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Expedition-Base-Set'}
# {'name': 'Explosive Flame Walker', 'id': '3219', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Explosive-Flame-Walker'}
# {'name': 'Extra Regulation Box', 'id': '4490', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Extra-Regulation-Box'}
# {'name': 'Facing a New Trial', 'id': '3946', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Facing-a-New-Trial'}
# {'name': 'Fairy Rise', 'id': '3871', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Fairy-Rise'}
# {'name': 'Fates Collide', 'id': '1706', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Fates-Collide'}
# {'name': 'Feraligatr Constructed Starter Deck', 'id': '5720', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Feraligatr-Constructed-Starter-Deck'}
# {'name': 'Fever-Burst Fighter', 'id': '3999', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Fever-Burst-Fighter'}
# {'name': 'Flashfire', 'id': '1583', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Flashfire'}
# {'name': 'Flight of Legends', 'id': '5714', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Flight-of-Legends'}
# {'name': 'Flygon Constructed Starter Deck', 'id': '5871', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Flygon-Constructed-Starter-Deck'}
# {'name': 'Forbidden Light', 'id': '2075', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Forbidden-Light'}
# {'name': 'Forbidden Light JP', 'id': '3896', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Forbidden-Light-JP'}
# {'name': 'Fossil', 'id': '1526', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Fossil'}
# {'name': 'Freeze Bolt', 'id': '4195', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Freeze-Bolt'}
# {'name': 'Full Metal Wall', 'id': '3841', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Full-Metal-Wall'}
# {'name': 'Furious Fists', 'id': '1584', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Furious-Fists'}
# {'name': 'Fusion Arts', 'id': '4360', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Fusion-Arts'}
# {'name': 'Fusion Strike', 'id': '4382', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Fusion-Strike'}
# {'name': 'Futsal Promos', 'id': '3510', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Futsal-Promos'}
# {'name': 'Future Flash', 'id': '5479', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Future-Flash'}
# {'name': 'Gaia Volcano', 'id': '4039', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Gaia-Volcano'}
# {'name': "Galactic's Conquest", 'id': '4297', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Galactics-Conquest'}
# {'name': 'Gallade SP Half Deck', 'id': '4287', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Gallade-SP-Half-Deck'}
# {'name': 'Garchomp Half Deck', 'id': '4198', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Garchomp-Half-Deck'}
# {'name': 'Garchomp SP Half Deck', 'id': '4285', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Garchomp-SP-Half-Deck'}
# {'name': 'Generations', 'id': '1693', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Generations'}
# {'name': 'Generations Start Decks', 'id': '5927', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Generations-Start-Decks'}
# {'name': 'Gengar VMAX High-Class Deck', 'id': '4241', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Gengar-VMAX-High-Class-Deck'}
# {'name': 'GG End', 'id': '3831', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/GG-End'}
# {'name': 'Gift Box Emerald', 'id': '5724', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Gift-Box-Emerald'}
# {'name': 'Gift Box Latias ex', 'id': '5866', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Gift-Box-Latias-ex'}
# {'name': 'Gift Box Latios ex', 'id': '5865', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Gift-Box-Latios-ex'}
# {'name': 'Gift Box Mew • Lucario', 'id': '4361', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Gift-Box-Mew--Lucario'}
# {'name': 'Giratina DPt Half Deck', 'id': '4296', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Giratina-DPt-Half-Deck'}
# {'name': 'Giratina Half Deck', 'id': '4301', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Giratina-Half-Deck'}
# {'name': 'Gold, Silver, to a New World...', 'id': '4506', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Gold-Silver-to-a-New-World'}
# {'name': 'Golden Sky, Silvery Ocean', 'id': '5711', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Golden-Sky-Silvery-Ocean'}
# {'name': 'Golduck BREAK + Palkia EX Combo Deck', 'id': '4099', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Golduck-BREAK--Palkia-EX-Combo-Deck'}
# {'name': 'Great Detective Pikachu', 'id': '3826', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Great-Detective-Pikachu'}
# {'name': 'Great Encounters', 'id': '1558', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Great-Encounters'}
# {'name': 'Guardians Rising', 'id': '1800', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Guardians-Rising'}
# {'name': 'Guren Town Gym', 'id': '5686', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Guren-Town-Gym'}
# {'name': 'GX Battle Boost', 'id': '3916', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/GX-Battle-Boost'}
# {'name': 'GX Starter Decks', 'id': '4251', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/GX-Starter-Decks'}
# {'name': 'GX Ultra Shiny', 'id': '3856', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/GX-Ultra-Shiny'}
# {'name': 'Gym Challenge', 'id': '1530', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Gym-Challenge'}
# {'name': 'Gym Heroes', 'id': '1529', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Gym-Heroes'}
# {'name': 'Hail Blizzard', 'id': '4208', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Hail-Blizzard'}
# {'name': 'Hanada City Gym', 'id': '5682', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Hanada-City-Gym'}
# {'name': 'HeartGold & SoulSilver', 'id': '1566', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/HeartGold--SoulSilver'}
# {'name': 'HeartGold Collection', 'id': '4273', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/HeartGold-Collection'}
# {'name': 'Heatran vs Regigigas Deck Kit', 'id': '4303', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Heatran-vs-Regigigas-Deck-Kit'}
# {'name': 'HGSS Black Star Promos', 'id': '1610', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/HGSS-Black-Star-Promos'}
# {'name': 'Hidden Fates', 'id': '2514', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Hidden-Fates'}
# {'name': 'Holon Phantom', 'id': '5703', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Holon-Phantom'}
# {'name': 'Holon Research Tower', 'id': '5709', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Holon-Research-Tower'}
# {'name': 'Holon Research Tower Fire Quarter Deck', 'id': '5717', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Holon-Research-Tower-Fire-Quarter-Deck'}
# {'name': 'Holon Research Tower Lightning Quarter Deck', 'id': '5715', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Holon-Research-Tower-Lightning-Quarter-Deck'}
# {'name': 'Holon Research Tower Water Quarter Deck', 'id': '5716', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Holon-Research-Tower-Water-Quarter-Deck'}
# {'name': 'HS Trainer Kit', 'id': '1629', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/HS-Trainer-Kit'}
# {'name': 'Hydreigon Half Deck', 'id': '4199', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Hydreigon-Half-Deck'}
# {'name': 'Hyper Metal Chain Deck', 'id': '4134', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Hyper-Metal-Chain-Deck'}
# {'name': 'Imprison! Gardevoir ex Constructed Standard Deck', 'id': '5695', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Imprison-Gardevoir-ex-Constructed-Standard-Deck'}
# {'name': 'Incandescent Arcana', 'id': '5127', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Incandescent-Arcana'}
# {'name': 'Infernape SP Half Deck', 'id': '4288', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Infernape-SP-Half-Deck'}
# {'name': 'Infinity Zone', 'id': '3274', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Infinity-Zone'}
# {'name': 'Inteleon VMAX High-Class Deck', 'id': '4242', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Inteleon-VMAX-High-Class-Deck'}
# {'name': 'Intense Fight in the Destroyed Sky', 'id': '4302', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Intense-Fight-in-the-Destroyed-Sky'}
# {'name': 'Intro Pack Bulbasaur', 'id': '5059', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Intro-Pack-Bulbasaur'}
# {'name': 'Intro Pack Neo Chikorita', 'id': '5061', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Intro-Pack-Neo-Chikorita'}
# {'name': 'Intro Pack Neo Totodile', 'id': '5062', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Intro-Pack-Neo-Totodile'}
# {'name': 'Intro Pack Squirtle', 'id': '5060', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Intro-Pack-Squirtle'}
# {'name': 'Islands Await You', 'id': '3956', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Islands-Await-You'}
# {'name': 'J Promos', 'id': '4352', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/J-Promos'}
# {'name': 'Jet Black Spirit', 'id': '4172', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Jet-Black-Spirit'}
# {'name': 'Jungle', 'id': '1525', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Jungle'}
# {'name': 'Keldeo Battle Strength Deck', 'id': '4197', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Keldeo-Battle-Strength-Deck'}
# {'name': 'Kuchiba City Gym', 'id': '5683', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Kuchiba-City-Gym'}
# {'name': 'L-P Promos', 'id': '4274', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/L-P-Promos'}
# {'name': "Leaders' Stadium", 'id': '4466', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Leaders-Stadium'}
# {'name': 'Leafeon Expert Deck', 'id': '4266', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Leafeon-Expert-Deck'}
# {'name': 'Legendary Collection', 'id': '1535', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Legendary-Collection'}
# {'name': 'Legendary Heartbeat', 'id': '3384', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Legendary-Heartbeat'}
# {'name': 'Legendary Shine Collection', 'id': '4114', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Legendary-Shine-Collection'}
# {'name': 'Legendary Treasures', 'id': '1581', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Legendary-Treasures'}
# {'name': 'Legends Awakened', 'id': '1560', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Legends-Awakened'}
# {'name': 'Lost Abyss', 'id': '5094', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Lost-Abyss'}
# {'name': 'Lost Link', 'id': '4262', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Lost-Link'}
# {'name': 'Lost Origin', 'id': '5093', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Lost-Origin'}
# {'name': 'Lost Thunder', 'id': '2370', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Lost-Thunder'}
# {'name': 'M Master Deck Build Box Power Style', 'id': '5915', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/M-Master-Deck-Build-Box-Power-Style'}
# {'name': 'M Master Deck Build Box Speed Style', 'id': '5914', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/M-Master-Deck-Build-Box-Speed-Style'}
# {'name': 'Magma Deck Kit', 'id': '5868', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Magma-Deck-Kit'}
# {'name': 'Magma Gang VS Aqua Gang: Double Crisis', 'id': '4124', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Magma-Gang-VS-Aqua-Gang-Double-Crisis'}
# {'name': 'Magma VS Aqua: Two Ambitions', 'id': '5869', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Magma-VS-Aqua-Two-Ambitions'}
# {'name': 'Magmortar Battle Starter Deck', 'id': '4269', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Magmortar-Battle-Starter-Deck'}
# {'name': 'Magmortar vs Electivire Deck Kit', 'id': '4307', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Magmortar-vs-Electivire-Deck-Kit'}
# {'name': 'Majestic Dawn', 'id': '1559', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Majestic-Dawn'}
# {'name': 'Mask of Change', 'id': '5690', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Mask-of-Change'}
# {'name': 'Master Deck Build Box EX', 'id': '4191', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Master-Deck-Build-Box-EX'}
# {'name': 'Master Kit', 'id': '5718', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Master-Kit'}
# {'name': 'Matchless Fighters', 'id': '3751', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Matchless-Fighters'}
# {'name': 'MAudino EX Mega Battle Deck', 'id': '4079', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/MAudino-EX-Mega-Battle-Deck'}
# {'name': "McDonald's Collection 2011", 'id': '1623', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/McDonalds-Collection-2011'}
# {'name': "McDonald's Collection 2012", 'id': '1624', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/McDonalds-Collection-2012'}
# {'name': "McDonald's Collection 2013", 'id': '2352', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/McDonalds-Collection-2013'}
# {'name': "McDonald's Collection 2014", 'id': '1625', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/McDonalds-Collection-2014'}
# {'name': "McDonald's Collection 2015", 'id': '1741', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/McDonalds-Collection-2015'}
# {'name': "McDonald's Collection 2016", 'id': '1752', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/McDonalds-Collection-2016'}
# {'name': "McDonald's Collection 2017", 'id': '1845', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/McDonalds-Collection-2017'}
# {'name': "McDonald's Collection 2018", 'id': '2404', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/McDonalds-Collection-2018'}
# {'name': "McDonald's Collection 2018 FR", 'id': '2361', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/McDonalds-Collection-2018-FR'}
# {'name': "McDonald's Collection 2019", 'id': '2829', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/McDonalds-Collection-2019'}
# {'name': "McDonald's Collection 2019 FR", 'id': '3354', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/McDonalds-Collection-2019-FR'}
# {'name': "McDonald's Collection 2024", 'id': '5978', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/McDonalds-Collection-2024'}
# {'name': "McDonald's Collection 25th Anniversary", 'id': '3738', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/McDonalds-Collection-25th-Anniversary'}
# {'name': "McDonald's Match Battle 2022", 'id': '5135', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/McDonalds-Match-Battle-2022'}
# {'name': "McDonald's Match Battle 2023", 'id': '5430', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/McDonalds-Match-Battle-2023'}
# {'name': "McDonald's Pokémon-e Minimum Pack", 'id': '4178', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/McDonalds-Pokémon-e-Minimum-Pack'}
# {'name': 'MCharizard EX Mega Battle Deck', 'id': '4139', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/MCharizard-EX-Mega-Battle-Deck'}
# {'name': 'Megalo Cannon', 'id': '4182', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Megalo-Cannon'}
# {'name': 'Meganium Constructed Starter Deck', 'id': '5722', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Meganium-Constructed-Starter-Deck'}
# {'name': 'Melee! Pokémon Scramble', 'id': '4277', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Melee-Pokémon-Scramble'}
# {'name': 'Metagross Constructed Starter Deck', 'id': '5863', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Metagross-Constructed-Starter-Deck'}
# {'name': 'Metagross Expert Deck', 'id': '4267', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Metagross-Expert-Deck'}
# {'name': 'Mewtwo LV.X Collection Pack', 'id': '4282', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Mewtwo-LVX-Collection-Pack'}
# {'name': 'Mewtwo vs Genesect Deck Kit', 'id': '4179', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Mewtwo-vs-Genesect-Deck-Kit'}
# {'name': 'Miracle Crystal', 'id': '5700', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Miracle-Crystal'}
# {'name': 'Miracle of the Desert', 'id': '5873', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Miracle-of-the-Desert'}
# {'name': 'Miracle Twin', 'id': '3816', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Miracle-Twin'}
# {'name': 'Mirage Forest', 'id': '5710', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Mirage-Forest'}
# {'name': "Mirage's Mew Constructed Starter Deck", 'id': '5719', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Mirages-Mew-Constructed-Starter-Deck'}
# {'name': 'Moonlit Pursuit', 'id': '4309', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Moonlit-Pursuit'}
# {'name': 'Movie Commemoration Random Pack', 'id': '4276', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Movie-Commemoration-Random-Pack'}
# {'name': 'Movie Commemoration VS Pack', 'id': '4348', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Movie-Commemoration-VS-Pack'}
# {'name': "Movie Commemoration VS Pack: Aura's Lucario", 'id': '4339', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Movie-Commemoration-VS-Pack-Auras-Lucario'}
# {'name': "Movie Commemoration VS Pack: Sea's Manaphy", 'id': '4319', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Movie-Commemoration-VS-Pack-Seas-Manaphy'}
# {'name': 'Movie Commemoration VS Pack: Sky-Splitting Deoxys', 'id': '4340', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Movie-Commemoration-VS-Pack-Sky-Splitting-Deoxys'}
# {'name': 'MRayquaza EX Mega Battle Deck', 'id': '4119', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/MRayquaza-EX-Mega-Battle-Deck'}
# {'name': 'Mudkip Constructed Starter Deck', 'id': '5874', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Mudkip-Constructed-Starter-Deck'}
# {'name': 'My First Battle', 'id': '5526', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/My-First-Battle'}
# {'name': 'Mysterious Mountains', 'id': '5025', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Mysterious-Mountains'}
# {'name': 'Mysterious Treasures', 'id': '1556', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Mysterious-Treasures'}
# {'name': 'Mystery of the Fossils', 'id': '4464', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Mystery-of-the-Fossils'}
# {'name': 'Mythical & Legendary Dream Shine Collection', 'id': '4069', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Mythical--Legendary-Dream-Shine-Collection'}
# {'name': 'National Pokédex Beginning Set', 'id': '4196', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/National-Pokédex-Beginning-Set'}
# {'name': 'Neo Destiny', 'id': '1534', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Neo-Destiny'}
# {'name': 'Neo Discovery', 'id': '1532', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Neo-Discovery'}
# {'name': 'Neo Genesis', 'id': '1531', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Neo-Genesis'}
# {'name': 'Neo Revelation', 'id': '1533', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Neo-Revelation'}
# {'name': 'Next Destinies', 'id': '1574', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Next-Destinies'}
# {'name': 'Night Unison', 'id': '3846', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Night-Unison'}
# {'name': 'Night Wanderer', 'id': '5757', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Night-Wanderer'}
# {'name': 'Nintendo Black Star Promos', 'id': '1608', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Nintendo-Black-Star-Promos'}
# {'name': 'Nivi City Gym', 'id': '5681', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Nivi-City-Gym'}
# {'name': 'Noble Victories', 'id': '1573', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Noble-Victories'}
# {'name': 'Noivern BREAK Evolution Pack', 'id': '4104', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Noivern-BREAK-Evolution-Pack'}
# {'name': 'Obsidian Flames', 'id': '5385', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Obsidian-Flames'}
# {'name': "Ocean's Kyogre ex Constructed Starter Deck", 'id': '5699', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Oceans-Kyogre-ex-Constructed-Starter-Deck'}
# {'name': 'Offense and Defense of the Furthest Ends', 'id': '5693', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Offense-and-Defense-of-the-Furthest-Ends'}
# {'name': 'P Promos', 'id': '4353', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/P-Promos'}
# {'name': 'Paldea Evolved', 'id': '5318', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Paldea-Evolved'}
# {'name': 'Paldean Fates', 'id': '5546', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Paldean-Fates'}
# {'name': 'Palkia DPt Half Deck', 'id': '4294', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Palkia-DPt-Half-Deck'}
# {'name': 'Palkia LV.X Constructed Standard Deck', 'id': '4311', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Palkia-LVX-Constructed-Standard-Deck'}
# {'name': 'Paradigm Trigger', 'id': '5156', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Paradigm-Trigger'}
# {'name': 'Paradise Dragona', 'id': '5846', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Paradise-Dragona'}
# {'name': 'Paradox Rift', 'id': '5444', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Paradox-Rift'}
# {'name': 'PCG Promos', 'id': '4341', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/PCG-Promos'}
# {'name': 'Phantom Forces', 'id': '1521', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Phantom-Forces'}
# {'name': 'Phantom Gate', 'id': '4044', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Phantom-Gate'}
# {'name': 'Pikachu DPt Half Deck', 'id': '4290', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Pikachu-DPt-Half-Deck'}
# {'name': 'Pikachu World Collection', 'id': '4392', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Pikachu-World-Collection'}
# {'name': "Pikachu's New Friends", 'id': '3979', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Pikachus-New-Friends'}
# {'name': 'Piplup DPt Half Deck', 'id': '4291', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Piplup-DPt-Half-Deck'}
# {'name': 'Plasma Blast', 'id': '1580', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Plasma-Blast'}
# {'name': 'Plasma Freeze', 'id': '1579', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Plasma-Freeze'}
# {'name': 'Plasma Gale', 'id': '4193', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Plasma-Gale'}
# {'name': 'Plasma Storm', 'id': '1578', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Plasma-Storm'}
# {'name': 'Platinum', 'id': '1562', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Platinum'}
# {'name': 'PLAY Promos', 'id': '4349', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/PLAY-Promos'}
# {'name': 'Play! Pokémon Prize Pack Series Five', 'id': '5849', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Play-Pokémon-Prize-Pack-Series-Five'}
# {'name': 'Play! Pokémon Prize Pack Series Four', 'id': '5620', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Play-Pokémon-Prize-Pack-Series-Four'}
# {'name': 'Play! Pokémon Prize Pack Series One', 'id': '5204', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Play-Pokémon-Prize-Pack-Series-One'}
# {'name': 'Play! Pokémon Prize Pack Series Three', 'id': '5431', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Play-Pokémon-Prize-Pack-Series-Three'}
# {'name': 'Play! Pokémon Prize Pack Series Two', 'id': '5313', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Play-Pokémon-Prize-Pack-Series-Two'}
# {'name': 'Poké Card Creator Pack', 'id': '4505', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Poké-Card-Creator-Pack'}
# {'name': 'PokéKyun Collection', 'id': '4094', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/PokéKyun-Collection'}
# {'name': 'Pokémon Card 151', 'id': '5328', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Pokémon-Card-151'}
# {'name': 'Pokémon Card Game Classic: Blastoise & Suicune ex Deck', 'id': '5529', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Pokémon-Card-Game-Classic-Blastoise--Suicune-ex-Deck'}
# {'name': 'Pokémon Card Game Classic: Charizard & Ho-Oh ex Deck', 'id': '5528', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Pokémon-Card-Game-Classic-Charizard--Ho-Oh-ex-Deck'}
# {'name': 'Pokémon Card Game Classic: Venusaur & Lugia ex Deck', 'id': '5527', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Pokémon-Card-Game-Classic-Venusaur--Lugia-ex-Deck'}
# {'name': 'Pokémon Card VS', 'id': '4168', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Pokémon-Card-VS'}
# {'name': 'Pokémon Card web', 'id': '4355', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Pokémon-Card-web'}
# {'name': 'Pokémon GO', 'id': '5051', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Pokémon-GO'}
# {'name': 'Pokémon GO Enhanced Expansion Pack', 'id': '4786', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Pokémon-GO-Enhanced-Expansion-Pack'}
# {'name': 'Pokémon Jungle', 'id': '4463', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Pokémon-Jungle'}
# {'name': 'Pokémon Products', 'id': '1645', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Pokémon-Products'}
# {'name': 'Pokémon Rumble', 'id': '1634', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Pokémon-Rumble'}
# {'name': 'Pokémon Trading Card Game Classic: Blastoise & Suicune ex Deck', 'id': '5532', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Pokémon-Trading-Card-Game-Classic-Blastoise--Suicune-ex-Deck'}
# {'name': 'Pokémon Trading Card Game Classic: Charizard & Ho-Oh ex Deck', 'id': '5531', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Pokémon-Trading-Card-Game-Classic-Charizard--Ho-Oh-ex-Deck'}
# {'name': 'Pokémon Trading Card Game Classic: Venusaur & Lugia ex Deck', 'id': '5530', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Pokémon-Trading-Card-Game-Classic-Venusaur--Lugia-ex-Deck'}
# {'name': 'PokéPark Blue', 'id': '4342', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/PokéPark-Blue'}
# ...
# {'name': 'Stellar Tera Type Starter Set Ceruledge ex', 'id': '5842', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Stellar-Tera-Type-Starter-Set-Ceruledge-ex'}
# {'name': 'Stellar Tera Type Starter Set Sylveon ex', 'id': '5841', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Stellar-Tera-Type-Starter-Set-Sylveon-ex'}
# {'name': 'Stormfront', 'id': '1561', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Stormfront'}
# {'name': 'Strength Expansion Pack Sun & Moon', 'id': '3961', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Strength-Expansion-Pack-Sun--Moon'}
# {'name': 'Sun & Moon', 'id': '1745', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Sun--Moon'}
# {'name': 'Sun & Moon Family Pokémon Card Game', 'id': '4246', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Sun--Moon-Family-Pokémon-Card-Game'}
# {'name': 'Sun & Moon Promos', 'id': '3324', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Sun--Moon-Promos'}
# {'name': 'Sun & Moon Starter Set', 'id': '4258', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Sun--Moon-Starter-Set'}
# {'name': 'Super Electric Breaker', 'id': '5901', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Super-Electric-Breaker'}
# {'name': 'Super Legend Set: Xerneas EX & Yveltal EX', 'id': '4129', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Super-Legend-Set-Xerneas-EX--Yveltal-EX'}
# {'name': 'Super-Burst Impact', 'id': '3866', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Super-Burst-Impact'}
# {'name': 'Supreme Victors', 'id': '1564', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Supreme-Victors'}
# {'name': 'Surging Sparks', 'id': '5879', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Surging-Sparks'}
# {'name': 'SV Black Star Promos', 'id': '5241', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/SV-Black-Star-Promos'}
# {'name': 'Sword', 'id': '3289', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Sword'}
# {'name': 'Sword & Shield', 'id': '2921', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Sword--Shield'}
# {'name': 'Sword & Shield Family Pokémon Card Game', 'id': '4243', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Sword--Shield-Family-Pokémon-Card-Game'}
# {'name': 'Sword & Shield Premium Trainer Box', 'id': '3615', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Sword--Shield-Premium-Trainer-Box'}
# {'name': 'Sword & Shield Promos', 'id': '3214', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Sword--Shield-Promos'}
# {'name': 'Sword & Shield Starter Decks', 'id': '3600', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Sword--Shield-Starter-Decks'}
# {'name': 'Sword & Shield Starter Set Darkrai VSTAR', 'id': '4517', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Sword--Shield-Starter-Set-Darkrai-VSTAR'}
# {'name': 'Sword & Shield Starter Set Lucario VSTAR', 'id': '4516', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Sword--Shield-Starter-Set-Lucario-VSTAR'}
# {'name': 'SWSH Black Star Promos', 'id': '2916', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/SWSH-Black-Star-Promos'}
# {'name': 'T Promos', 'id': '4354', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/T-Promos'}
# {'name': 'Tag Bolt', 'id': '3851', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Tag-Bolt'}
# {'name': 'Tag Team GX Deck Build Box', 'id': '4247', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Tag-Team-GX-Deck-Build-Box'}
# {'name': 'Tag Team GX Premium Trainer Box', 'id': '4249', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Tag-Team-GX-Premium-Trainer-Box'}
# {'name': 'Tag Team GX Starter Sets', 'id': '4245', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Tag-Team-GX-Starter-Sets'}
# {'name': 'Tag Team GX: Tag All Stars', 'id': '3776', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Tag-Team-GX-Tag-All-Stars'}
# {'name': 'Tamamushi City Gym', 'id': '5684', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Tamamushi-City-Gym'}
# {'name': 'Tapu Bulu GX Enhanced Starter Set', 'id': '4255', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Tapu-Bulu-GX-Enhanced-Starter-Set'}
# {'name': 'Team Plasma Battle Gift Set', 'id': '4188', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Team-Plasma-Battle-Gift-Set'}
# {'name': "Team Plasma's Powered Half Deck", 'id': '4192', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Team-Plasmas-Powered-Half-Deck'}
# {'name': 'Team Rocket', 'id': '1528', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Team-Rocket'}
# {'name': 'Team Up', 'id': '2407', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Team-Up'}
# {'name': 'Temple of Anger', 'id': '4304', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Temple-of-Anger'}
# {'name': 'Temporal Forces', 'id': '5589', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Temporal-Forces'}
# {'name': 'Terastal Festival ex', 'id': '5928', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Terastal-Festival-ex'}
# {'name': 'Terastal Starter Set Mewtwo ex', 'id': '5477', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Terastal-Starter-Set-Mewtwo-ex'}
# {'name': 'Terastal Starter Set Skeledirge ex', 'id': '5476', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Terastal-Starter-Set-Skeledirge-ex'}
# {'name': 'The Best of XY', 'id': '3984', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/The-Best-of-XY'}
# {'name': 'The Town on No Map', 'id': '5022', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/The-Town-on-No-Map'}
# {'name': 'Theater Limited VS Pack', 'id': '4351', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Theater-Limited-VS-Pack'}
# {'name': 'Thunder Knuckle', 'id': '4185', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Thunder-Knuckle'}
# {'name': 'Thunderclap Spark', 'id': '3876', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Thunderclap-Spark'}
# {'name': 'Tidal Storm', 'id': '4034', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Tidal-Storm'}
# {'name': 'Time Gazer', 'id': '4973', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Time-Gazer'}
# {'name': 'To Have Seen the Battle Rainbow', 'id': '3941', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/To-Have-Seen-the-Battle-Rainbow'}
# {'name': 'Torchic Constructed Starter Deck', 'id': '5875', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Torchic-Constructed-Starter-Deck'}
# {'name': 'Torterra Battle Starter Deck', 'id': '4268', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Torterra-Battle-Starter-Deck'}
# {'name': 'Towering Perfection', 'id': '4329', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Towering-Perfection'}
# {'name': 'Traditional Chinese Products', 'id': '5960', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Traditional-Chinese-Products'}
# {'name': 'Trainer Battle Decks', 'id': '4248', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Trainer-Battle-Decks'}
# {'name': 'Treecko Constructed Starter Deck', 'id': '5876', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Treecko-Constructed-Starter-Deck'}
# {'name': 'Trick or Trade', 'id': '5138', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Trick-or-Trade'}
# {'name': 'Trick or Trade 2023', 'id': '5405', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Trick-or-Trade-2023'}
# {'name': 'Trick or Trade 2024', 'id': '5796', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Trick-or-Trade-2024'}
# {'name': 'Triplet Beat', 'id': '5257', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Triplet-Beat'}
# {'name': 'Triumphant', 'id': '1569', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Triumphant'}
# {'name': 'Turtwig DPt Half Deck', 'id': '4292', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Turtwig-DPt-Half-Deck'}
# {'name': 'Twilight Masquerade', 'id': '5691', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Twilight-Masquerade'}
# {'name': 'Typhlosion Constructed Starter Deck', 'id': '5721', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Typhlosion-Constructed-Starter-Deck'}
# {'name': 'Tyranitar Constructed Standard Deck', 'id': '4263', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Tyranitar-Constructed-Standard-Deck'}
# {'name': 'Ultra Force', 'id': '3901', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Ultra-Force'}
# {'name': 'Ultra Moon', 'id': '3906', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Ultra-Moon'}
# {'name': 'Ultra Prism', 'id': '2065', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Ultra-Prism'}
# {'name': 'Ultra Sun', 'id': '3911', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Ultra-Sun'}
# {'name': 'Ultra Sun & Ultra Moon Deck Build Boxes', 'id': '4252', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Ultra-Sun--Ultra-Moon-Deck-Build-Boxes'}
# {'name': 'Ultra Sun & Ultra Moon Premium Trainer Box', 'id': '4253', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Ultra-Sun--Ultra-Moon-Premium-Trainer-Box'}
# {'name': 'Ultradimensional Beasts', 'id': '3921', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Ultradimensional-Beasts'}
# {'name': 'Unbroken Bonds', 'id': '2437', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Unbroken-Bonds'}
# {'name': 'Undaunted', 'id': '1568', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Undaunted'}
# {'name': 'Undone Seal', 'id': '5864', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Undone-Seal'}
# {'name': 'Unified Minds', 'id': '2487', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Unified-Minds'}
# {'name': 'Unleashed', 'id': '1567', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Unleashed'}
# {'name': 'Unnumbered Promos', 'id': '4170', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Unnumbered-Promos'}
# {'name': 'V Starter Decks', 'id': '3389', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/V-Starter-Decks'}
# {'name': 'V-UNION Special Card Sets', 'id': '4381', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/V-UNION-Special-Card-Sets'}
# {'name': 'Venusaur & Charizard & Blastoise Special Deck Set ex', 'id': '5525', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Venusaur--Charizard--Blastoise-Special-Deck-Set-ex'}
# {'name': 'Venusaur, Charizard & Blastoise Random Constructed Starter Decks', 'id': '5729', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Venusaur-Charizard--Blastoise-Random-Constructed-Starter-Decks'}
# {'name': 'Violet ex', 'id': '5217', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Violet-ex'}
# {'name': 'Vivid Voltage', 'id': '3484', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Vivid-Voltage'}
# {'name': 'VMAX Climax', 'id': '4390', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/VMAX-Climax'}
# {'name': 'VMAX Rising', 'id': '3284', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/VMAX-Rising'}
# {'name': 'VMAX Special Set', 'id': '3610', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/VMAX-Special-Set'}
# {'name': 'VMAX Starter Deck: Blastoise VMAX', 'id': '3590', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/VMAX-Starter-Deck-Blastoise-VMAX'}
# {'name': 'VMAX Starter Deck: Venusaur VMAX', 'id': '3585', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/VMAX-Starter-Deck-Venusaur-VMAX'}
# {'name': 'VMAX Starter Decks', 'id': '3595', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/VMAX-Starter-Decks'}
# {'name': 'VSTAR & VMAX High Class Deck Deoxys', 'id': '5097', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/VSTAR--VMAX-High-Class-Deck-Deoxys'}
# {'name': 'VSTAR & VMAX High Class Deck Zeraora', 'id': '5096', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/VSTAR--VMAX-High-Class-Deck-Zeraora'}
# {'name': 'VSTAR Special Set', 'id': '5098', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/VSTAR-Special-Set'}
# {'name': 'VSTAR Universe', 'id': '5198', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/VSTAR-Universe'}
# {'name': 'White Collection', 'id': '4213', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/White-Collection'}
# {'name': 'White Kyurem EX Battle Strength Deck', 'id': '4189', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/White-Kyurem-EX-Battle-Strength-Deck'}
# {'name': 'Wild Blaze', 'id': '4054', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Wild-Blaze'}
# {'name': 'Wild Force', 'id': '5573', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Wild-Force'}
# {'name': 'Wind from the Sea', 'id': '5023', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Wind-from-the-Sea'}
# {'name': 'Wizards Black Star Promos', 'id': '1607', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Wizards-Black-Star-Promos'}
# {'name': 'World Champions Pack', 'id': '4314', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/World-Champions-Pack'}
# {'name': 'World Championships 2023 Yokohama Deck -Pikachu-', 'id': '5410', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/World-Championships-2023-Yokohama-Deck--Pikachu-'}
# {'name': 'Xerneas Half Deck', 'id': '4149', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Xerneas-Half-Deck'}
# {'name': 'XY', 'id': '1582', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/XY'}
# {'name': 'XY Beginning Set', 'id': '4154', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/XY-Beginning-Set'}
# {'name': 'XY Black Star Promos', 'id': '1612', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/XY-Black-Star-Promos'}
# {'name': 'XY Kalos Starter Set', 'id': '1637', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/XY-Kalos-Starter-Set'}
# {'name': 'XY Promos', 'id': '4159', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/XY-Promos'}
# {'name': 'XY Trainer Kit', 'id': '1631', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/XY-Trainer-Kit'}
# {'name': 'XY Trainer Kit: Bisharp & Wigglytuff', 'id': '1632', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/XY-Trainer-Kit-Bisharp--Wigglytuff'}
# {'name': 'XY Trainer Kit: Latias & Latios', 'id': '1683', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/XY-Trainer-Kit-Latias--Latios'}
# {'name': 'XY Trainer Kit: Pikachu Libre & Suicune', 'id': '1707', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/XY-Trainer-Kit-Pikachu-Libre--Suicune'}
# {'name': 'Yamabuki City Gym', 'id': '5685', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Yamabuki-City-Gym'}
# {'name': 'Yveltal Half Deck', 'id': '4144', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Yveltal-Half-Deck'}
# {'name': 'Zacian + Zamazenta BOX', 'id': '3605', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Zacian--Zamazenta-BOX'}
# {'name': 'Zekrom EX Battle Strength Deck', 'id': '4206', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Zekrom-EX-Battle-Strength-Deck'}
# {'name': 'Zygarde EX Perfect Battle Deck', 'id': '4084', 'link': 'https://www.cardmarket.com/en/Pokemon/Products/Singles/Zygarde-EX-Perfect-Battle-Deck'}
#
# Set data saved to 'pokemon_sets.json'

# %%
import json
import unidecode

def correct_links(input_file, output_file):
    """
    Reads a JSON file with incorrect links, processes the links to fix them, 
    and writes the corrected links to a new JSON file.
    
    :param input_file: Path to the original JSON file with incorrect links.
    :param output_file: Path to the new JSON file with corrected links.
    """
    with open(input_file, 'r', encoding='utf-8') as file:
        data = json.load(file)
    
    corrected_data = []

    for entry in data:
        name = entry['name']
        corrected_link = (
            'https://www.cardmarket.com/en/Pokemon/Products/Singles/' +
            unidecode.unidecode(name)       # Normalize accented characters
                .replace(' & ', '-')        # Replace " & " with "-"
                .replace(':', '')           # Remove colons
                .replace('.', '')           # Remove dots
                .replace(',', '')           # Remove commas
                .replace('"', '')           # Remove double quotes
                .replace("'", '')           # Remove single quotes
                .replace('+', '-')          # Replace plus signs with hyphens
                .replace('!', '')           # Remove exclamation marks
                .replace('...', '')         # Remove ellipses
                .replace('•', '')           # Remove bullet points
                .replace('*', '-')          # Replace asterisks with hyphens
                .replace(' ', '-')          # Replace spaces with "-"
        )
        # Ensure no double hyphens
        while '--' in corrected_link:
            corrected_link = corrected_link.replace('--', '-')
        
        corrected_link += '?idRarity=0&perSite=20'  # Add the fixed parameters

        corrected_entry = {
            'name': entry['name'],
            'id': entry['id'],
            'link': corrected_link
        }
        corrected_data.append(corrected_entry)

    with open(output_file, 'w', encoding='utf-8') as file:
        json.dump(corrected_data, file, indent=2, ensure_ascii=False)

    print(f"Corrected links saved to {output_file}")

# Example usage
input_file = 'pokemon_sets.json'  # Replace with the path to your original JSON file
output_file = 'corrected_pokemon_sets.json'  # Path for the new JSON file with corrected links
correct_links(input_file, output_file)
# Out:
# Corrected links saved to corrected_pokemon_sets.json

# %%
import json
import re

def validate_links(file_path):
    """
    Validates the links in a JSON file to ensure they do not contain problematic characters.
    Prints problematic links with their respective issues.

    :param file_path: Path to the JSON file with links to validate.
    """
    # Define a regex pattern for valid URL characters
    valid_url_pattern = re.compile(r'^[a-zA-Z0-9:/?&=_\-%.]+$')

    with open(file_path, 'r', encoding='utf-8') as file:
        data = json.load(file)

    problematic_links = []

    for entry in data:
        link = entry['link']
        if not valid_url_pattern.match(link):
            problematic_links.append({'name': entry['name'], 'id': entry['id'], 'link': link})

    if problematic_links:
        print(f"Found {len(problematic_links)} problematic links:")
        for problem in problematic_links:
            print(f"Name: {problem['name']}, ID: {problem['id']}, Link: {problem['link']}")
    else:
        print("All links are valid!")

# Example usage
file_path = 'corrected_pokemon_sets.json'  # Replace with the path to your JSON file
validate_links(file_path)
# Out:
# All links are valid!

# %% [markdown]
# ## Now check the console output and identify the problematic sets:
# ### they have eithor more than 15 pages of data, or invalid link

# %%
import re

def extract_problematic_sets(file_path, output_file):
    """
    Extracts names and links of sets that processed exactly 15 pages
    from a console output log file. Saves the problematic sets to a JSON file.

    :param file_path: Path to the console output file.
    :param output_file: Path to save the extracted problematic sets as JSON.
    """
    import json

    # Regular expressions to match relevant lines
    fetch_pattern = re.compile(r"Fetching: (.+?) \((https://.+?)\)")
    processing_pattern = re.compile(r"Processing page (\d+) for (.+)")
    last_page_pattern = re.compile(r"Reached the last page for (.+)")
    
    # Store data about sets
    sets = {}
    problematic_sets = []

    # Read the file line by line
    with open(file_path, 'r', encoding='utf-8') as file:
        for line in file:
            # Match the "Fetching" line to get set name and link
            fetch_match = fetch_pattern.match(line)
            if fetch_match:
                name, link = fetch_match.groups()
                sets[name] = {"link": link, "pages": 0}

            # Match the "Processing page" line to track pages processed
            processing_match = processing_pattern.match(line)
            if processing_match:
                page_number, name = processing_match.groups()
                page_number = int(page_number)
                if name in sets:
                    sets[name]["pages"] = max(sets[name]["pages"], page_number)

            # Match the "Reached the last page" line to confirm last page processing
            last_page_match = last_page_pattern.match(line)
            if last_page_match:
                name = last_page_match.group(1)
                if name in sets and sets[name]["pages"] == 15:
                    problematic_sets.append({"name": name, "link": sets[name]["link"]})

    # Save problematic sets to JSON
    with open(output_file, 'w', encoding='utf-8') as output:
        json.dump(problematic_sets, output, indent=2, ensure_ascii=False)

    print(f"Extracted {len(problematic_sets)} problematic sets.")
    print(f"Results saved to {output_file}")

# Example usage
console_output_file = 'console_output.txt'  # Path to your console output file
problematic_sets_file = 'problematic_sets.json'  # Path to save problematic sets
extract_problematic_sets(console_output_file, problematic_sets_file)
# Out:
# Extracted 30 problematic sets.
# Results saved to problematic_sets.json
